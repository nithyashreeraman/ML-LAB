# %% [markdown]
# # DIANA

# %% [markdown]
# # NITHYASHREE 20BCE0969

# %%
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('iris.csv')

# %%
attr=df.columns.values[0:-1]
target=df[df.columns.values[-1]].values.tolist()
data=df[attr]

# %%
data=np.array(data)

# %%
def distance_function(x, y):
    return np.sqrt(np.sum((x - y) ** 2))

# compute pairwise distance matrix
D = squareform(pdist(data, distance_function))

# perform hierarchical clustering
Z = linkage(D, method='ward')
# Out:
# C:\Users\nithy\AppData\Local\Temp\ipykernel_27192\1158121362.py:8: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(D, method='ward')

# %%
fig, ax = plt.subplots(figsize=(10, 6))
dendrogram(Z, labels=list(range(len(data))), orientation='top')
ax.set_title('Dendrogram')
ax.set_xlabel('Samples')
ax.set_ylabel('Distance')
plt.show()
